# %% [markdown]
# # seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
fly=pd.read_csv('flight.csv')

# %%
fly.head()
# Out:
#    Year  Month  Day  DayOfWeek Flight_Date UniqueCarrier Tai_lNum  FlightNum  \
# 0  2016      7    1          5  01/07/2016            AA   N793AA          1
# 1  2016      7    2          6  02/07/2016            AA   N784AA          1
# 2  2016      7    4          1  04/07/2016            AA   N785AA          1
# 3  2016      7    5          2  05/07/2016            AA   N790AA          1
# 4  2016      7    6          3  06/07/2016            AA   N799AA          1
#
#   Origin_Airport Origin_City_Name  ... Carrier_Delay  WeatherDelay  NAS_Delay  \
# 0            BOS       Boston, MA  ...             0             0          0
# 1            BOS       Boston, MA  ...             0             0          0
# 2            BOS       Boston, MA  ...             0             0          0
# 3            BOS       Boston, MA  ...             0             0          0
# 4            BOS       Boston, MA  ...             0             0          0
#
# ...

# %% [markdown]
# #### using data set

# %%
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# sns.relplot("Flight_Date","Tai_lNum",data=fly)

# %% [markdown]
# ### numerical data ploting

# %% [markdown]
# #### rel plot()
# #### scatter plot()
# #### line plot()

# %%
sns.set(style='darkgrid')

# %%
sns.relplot(x='total_bill',y='tip',data=tips)

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='time')

# %%
tips['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker')

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=tips,style='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,size='size',sizes=(110,250))

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,style='size',color='cyan',sizes=(500,250),kind='line')

# %%
from numpy.random import random as rand

# %%
df=pd.DataFrame(dict(time=np.arange(500), value=rand(500).cumsum()))

# %%
df.head()
# Out:
#    time     value
# 0     0  0.974791
# 1     1  1.698806
# 2     2  2.085137
# 3     3  2.666729
# 4     4  2.693901

# %%
sns.relplot(x='time',y='value',kind='line',data=df,sort='False')

# %% [markdown]
# #### using fari -dataset

# %%
fmri=sns.load_dataset('fmri')

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line',ci=False)

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line',ci='sd')

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line',estimator=None)

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line',hue='region',size='subject')

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line',hue='region',style='event',markers=True,dashes=False)

# %%
sns.relplot(x='timepoint',y='signal',data=fmri,kind='line',hue='region',estimator=None,units='subject')

# %%
sns.relplot(x='timepoint',y='signal',kind='line',hue='region',estimator=None,units='subject',data=fmri.query("event=='stim'"))

# %%
dots = sns.load_dataset("dots").query("align == 'dots'")
sns.relplot(x="time", y="firing_rate",
            hue="coherence", style="choice",
            kind="line", data=dots);

# %%
palette = sns.cubehelix_palette(light=.8, n_colors=6)
sns.relplot(x="time", y="firing_rate",
            hue="coherence", style="choice",
            palette=palette,
            kind="line", data=dots);

# %%
sns.relplot(x="time", y="firing_rate",
            size="coherence", style="choice",
            kind="line", data=dots);

# %%
sns.relplot(x="time", y="firing_rate",hue="coherence", size="choice",palette=palette,sizes=(90,50),kind="line", data=dots);

# %% [markdown]
# #### line plot()

# %%
sns.lineplot(x='total_bill',y='tip',data=tips,hue='smoker')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### scatter plot()

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='smoker')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %% [markdown]
# ### visualizing distribution of data
#
# #### distplot
# #### kde plot
# #### joint plot
# #### rug

# %%
crashes=sns.load_dataset('car_crashes')

# %%
crashes.dtypes
# Out:
# total             float64
# speeding          float64
# alcohol           float64
# not_distracted    float64
# no_previous       float64
# ins_premium       float64
# ins_losses        float64
# abbrev             object
# dtype: object

# %%
crashes
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# #### distribution plot

# %%
sns.distplot(crashes['not_distracted'],kde=False,bins=15)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='not_distracted'>

# %%
crashes.corr()
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
sns.heatmap(crashes.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Joint plot (to do univariate analysis)

# %%
sns.jointplot(x='speeding',y='alcohol',data=crashes,kind='hex')

# %%
sns.jointplot(x='speeding',y='alcohol',data=crashes,kind='reg')

# %% [markdown]
# #### pair plot (for more than 2 variables)

# %%
crashes.dtypes
# Out:
# total             float64
# speeding          float64
# alcohol           float64
# not_distracted    float64
# no_previous       float64
# ins_premium       float64
# ins_losses        float64
# abbrev             object
# dtype: object

# %%
# crashes.drop(['abbrev'],axis=1)

# %%
sns.pairplot(crashes)

# %%
tips_df=pd.DataFrame(tips)

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Dist plot (univariate analysis)

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.displot(penguins, x="flipper_length_mm")

# %%
sns.displot(penguins, x="flipper_length_mm", binwidth=3)

# %%
sns.displot(tips, x="size")

# %%
sns.displot(tips, x="day", shrink=.8)

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species")

# %%
# One option is to change the visual representation of the histogram from a bar plot to a “step” plot:
sns.displot(penguins, x="flipper_length_mm", hue="species", element="step")

# %% [markdown]
# ##### kernel density estimation

# %%
sns.displot(penguins, x="flipper_length_mm", kind="kde")

# %% [markdown]
# #### rug plot()

# %%
sns.rugplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %% [markdown]
# ### categorical data ploting

# %% [markdown]
# #### cat plot
# #### box plot
# #### strip plot
# #### swarm plot
# #### violin plot
# #### count plot
# #### bar plot

# %% [markdown]
# ##### count plot()

# %%
#either 'x' or 'y' is enough
sns.countplot('sex',data=tips)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot('day',data=tips)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(y='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='count', ylabel='sex'>

# %% [markdown]
# ###### bar plot()

# %%
# both x and y are essential

sns.barplot(x='sex', y='body_mass_g',data=penguins)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='body_mass_g'>

# %% [markdown]
# ##### box plot()

# %%
sns.boxplot(x='sex', y='body_mass_g',data=penguins)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='body_mass_g'>

# %%
sns.boxplot(x='sex', y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(data=crashes,orient='v')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### violin plot()

# %%
# its a combination of both box plot and KDE 
sns.violinplot(y='sex', x='body_mass_g',data=penguins,pallete='rainbow')
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='sex'>

# %% [markdown]
# ##### cat plot()

# %%
sns.catplot(x='sex',y='total_bill',data=tips,palette='rainbow',jitter=False)

# %%
sns.catplot(x='sex',y='total_bill',data=tips,palette='rainbow',jitter=True)

# %%
sns.catplot(x='sex',y='total_bill',data=tips,palette='rainbow',jitter=True,hue='smoker')

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='box',hue='smoker')

# %%
sns.catplot(x='sex',y='total_bill',data=tips,kind='box',hue='smoker',dodge=False)

# %%
diamonds = sns.load_dataset("diamonds")

# %%
sns.catplot(x="color", y="price", kind="boxen",data=diamonds.sort_values("color"))

# %% [markdown]
# ### Linear reg & relationship

# %% [markdown]
# ##### reg plot()

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ##### lmp ploy()

# %%
# This function combines regplot() and FacetGrid 
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %% [markdown]
# ### Controlling figure aesthetics

# %% [markdown]
# ##### Seaborn figure styles

# %%
sns.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
sns.set_style("ticks")
sinplot()

# %% [markdown]
# ##### axex  styles

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': False,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sinplot()
