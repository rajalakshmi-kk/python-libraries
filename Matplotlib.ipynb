# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import pandas as numpy
import numpy as np

# %%
x = np.arange(0,10)
y = np.arange(11,21)

# %% [markdown]
# #### scatter plor

# %%
plt.scatter(x,y,color="red")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("2D graph")
# Out:
# Text(0.5, 1.0, '2D graph')

# %% [markdown]
# #### plot

# %%
y = x*x

# %%
plt.plot(x,y,'c*',linestyle='dashed',linewidth=2, markersize=10)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("2D diagram")
# Out:
# Text(0.5, 1.0, '2D diagram')

# %%
cat = ["bored", "happy", "bored", "bored", "happy", "bored"]
dog = ["happy", "happy", "happy", "happy", "bored", "bored"]
activity = ["combing", "drinking", "feeding", "napping", "playing", "washing"]

fig, ax = plt.subplots()
ax.plot(activity, dog, label="dog")
ax.plot(activity, cat, label="cat")
ax.legend()

plt.show()

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

# %%
plt.plot(xpoints, ypoints)

# %% [markdown]
# ##### subplots

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'c*')

plt.subplot(2,2,2)
plt.plot(x,y,'mo')

plt.subplot(2,2,3)
plt.plot(x,y,'y--')

plt.subplot(2,2,4)
plt.plot(x,y,'k*--')

# %%
x = np.arange(1,11)

# %% [markdown]
# #### sine curve

# %%
x = np.arange(0,8 * np.pi, 0.1)
y = np.sin(x)
plt.title("sine wave form")

plt.plot(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt
ax = plt.subplot(111)
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)
plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )
plt.ylim(-2,2)
plt.show()

# %% [markdown]
# #### subplot of sin graph

# %%
x = np.arange(1,12,0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)

plt.subplot(3,1,1)

plt.plot(x,y_sin,'y')
plt.title('sine')


plt.subplot(2,1,2)
plt.plot(x,y_cos,'c')
plt.title('cosine')
# Out:
# Text(0.5, 1.0, 'cosine')

# %% [markdown]
# #### bar plot

# %%
x1=[32,55,76,90,43]
y1=[75,96,34,13,52]

x2=[66,41,52,99,78]
y2=[44,84,97,61,80]

plt.bar(x1,y1,width=6,color="yellow")
plt.bar(x2,y2,width=4,color="black")

plt.title("bar diagram")
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %% [markdown]
# ##### Histogram

# %%
Q=np.array([32,55,76,90,43,75,96,34,13,52])
plt.hist(Q,color="cyan")
plt.title("Histogram")
plt.xlabel("x axis-the given number")
plt.ylabel("y axis-the density of given number")
# Out:
# Text(0, 0.5, 'y axis-the density of given number')

# %%
x1=[32,55,76,90,43]
#y1=[75,96,34,13,52]

plt.hist(x1,color="magenta",bins=8)
plt.title("Histogram")
plt.xlabel("x axis-the given number")
plt.ylabel("y axis-the density of given number")
# Out:
# Text(0, 0.5, 'y axis-the density of given number')

# %% [markdown]
# ##### BOX PLOT

# %%
data=[np.random.normal(0,std,80) for std in range(1,5)]

plt.boxplot(data,vert=True,patch_artist=True);

# %%
data=[np.random.normal(0,std,80) for std in range(1,5)]

plt.boxplot(data,vert=False,patch_artist=False);

# %%
data
# Out:
# [array([ 0.01095169, -1.84484932, -1.09949069, -0.09631669,  0.83957168,
#         -1.35058157, -1.29026267,  0.18606069,  0.23366206, -0.49428408,
#         -0.35860886, -0.82025688, -0.39201063,  0.25731293,  0.6822376 ,
#          2.33808768, -0.24076692,  0.48422148,  1.23044249, -0.83137968,
#          0.80211923, -3.70183793, -1.53048303, -0.62791495, -1.48411127,
#         -1.14576575, -1.15081853,  0.3620567 , -0.58493586, -1.45054415,
#         -0.70348778, -1.51605628, -0.09398259,  0.29115116,  1.83361829,
#         -0.07625978,  0.00411542, -1.03743815, -0.57366088, -0.98644134,
#          0.61883018, -1.71690581,  0.51434539, -1.0683778 , -0.78180395,
#          0.77020508, -0.51619778, -0.00566961,  0.1404522 , -1.31197698,
#          0.97866025, -2.43778981, -0.98785375, -0.10500835,  0.07263033,
#         -0.17020801, -1.1978244 , -0.35715955, -1.34470944, -0.85916044,
#         -0.76717217, -0.04949218, -0.19921628,  3.42229946, -0.74500954,
# ...

# %% [markdown]
# #### pei chart

# %%
# data to plot
labels="Python","C","Java","C++"
sizes=[400,398,412,208]
colors="gold","lightcoral","skyblue","grey"
explode=(0,0,0.2,0)

plt.pie(sizes,labels=labels,explode=explode,colors=colors,shadow=True,autopct='%1.1f%%');
plt.axis("equal")
plt.show()

# %% [markdown]
# ### stack plot

# %%
activity = [1,2,3,4,5]


fish = [100,300,500,700]
dog = [80,90,60,50]
rabbit=[30,40,10,20]

plt.stackplot(fish,dog,rabbit,colors =['m','c','y'],linewidth=14)
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
minutes = [1, 2, 3, 4, 5, 6, 7, 8, 9]

player1 = [8, 6, 5, 5, 4, 2, 1, 1, 0]
player2 = [0, 1, 2, 2, 2, 4, 4, 4, 4]
player3 = [0, 1, 1, 1, 2, 2, 3, 3, 4]

labels = ['player1', 'player2', 'player3']
colors = ['#6d904f', '#fc4f30', '#008fd5']

plt.stackplot(minutes, player1, player2, player3, labels=labels, colors=colors)

plt.legend(loc=(0.07, 0.05))

plt.title("My Awesome Stack Plot")
plt.tight_layout()

# %% [markdown]
# #### date & time series

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import (YEARLY, DateFormatter,
                              rrulewrapper, RRuleLocator, drange)
import numpy as np
import datetime

# Fixing random state for reproducibility
np.random.seed(19680801)


# tick every 5th easter
rule = rrulewrapper(YEARLY, byeaster=1, interval=5)
loc = RRuleLocator(rule)
formatter = DateFormatter('%m/%d/%y')
date1 = datetime.date(1952, 1, 1)
date2 = datetime.date(2004, 4, 12)
delta = datetime.timedelta(days=100)

dates = drange(date1, date2, delta)
s = np.random.rand(len(dates))  # make up some random y values


fig, ax = plt.subplots()
plt.plot_date(dates, s)
ax.xaxis.set_major_locator(loc)
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_tick_params(rotation=30, labelsize=10)

plt.show()
